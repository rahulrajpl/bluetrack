# %% [markdown]
# ### Reference
# https://machinelearningmastery.com/arima-for-time-series-forecasting-with-python/

# %%
from pandas import read_csv
from pandas import datetime
from matplotlib import pyplot

def parser(x):
    return datetime.strptime('190'+x, '%Y-%m')

series = read_csv('shampoo.csv', header=0, parse_dates=[0], index_col=0, squeeze=True, date_parser=parser)
print(series.head())
series.plot()
pyplot.show()
# Out:
# Month
# 1901-01-01    266.0
# 1901-02-01    145.9
# 1901-03-01    183.1
# 1901-04-01    119.3
# 1901-05-01    180.3
# Name: Sales, dtype: float64

# %%
# Finding autocorrelation with pandas
from pandas import read_csv
from pandas import datetime
from matplotlib import pyplot
from pandas.plotting import autocorrelation_plot

def parser(x):
    return datetime.strptime('190'+x, '%Y-%m')

series = read_csv('shampoo.csv', header=0, parse_dates=[0], index_col=0, squeeze=True, date_parser=parser)
autocorrelation_plot(series)
pyplot.show()

# %%
from pandas import read_csv
from pandas import datetime
from pandas import DataFrame
from statsmodels.tsa.arima_model import ARIMA
from matplotlib import pyplot

def parser(x):
	return datetime.strptime('190'+x, '%Y-%m')

series = read_csv('shampoo.csv', header=0, parse_dates=[0], index_col=0, squeeze=True, date_parser=parser)
# fit model
model = ARIMA(series, order=(5,1,0))
model_fit = model.fit(disp=0)
print(model_fit.summary())
# plot residual errors
residuals = DataFrame(model_fit.resid)
residuals.plot()
pyplot.show()
residuals.plot(kind='kde')
pyplot.show()
print(residuals.describe())
# Out:
# /home/rahul/.local/lib/python3.7/site-packages/statsmodels/tsa/base/tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# /home/rahul/.local/lib/python3.7/site-packages/statsmodels/tsa/base/tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
#                              ARIMA Model Results
# ==============================================================================
# Dep. Variable:                D.Sales   No. Observations:                   35
# Model:                 ARIMA(5, 1, 0)   Log Likelihood                -196.170
# Method:                       css-mle   S.D. of innovations             64.241
# Date:                Tue, 18 Feb 2020   AIC                            406.340
# Time:                        10:51:45   BIC                            417.227
# Sample:                    02-01-1901   HQIC                           410.098
#                          - 12-01-1903
# =================================================================================
#                     coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const            12.0649      3.652      3.304      0.001       4.908      19.222
# ar.L1.D.Sales    -1.1082      0.183     -6.063      0.000      -1.466      -0.750
# ar.L2.D.Sales    -0.6203      0.282     -2.203      0.028      -1.172      -0.068
# ar.L3.D.Sales    -0.3606      0.295     -1.222      0.222      -0.939       0.218
# ar.L4.D.Sales    -0.1252      0.280     -0.447      0.655      -0.674       0.424
# ar.L5.D.Sales     0.1289      0.191      0.673      0.501      -0.246       0.504
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1           -1.0617           -0.5064j            1.1763           -0.4292
# AR.2           -1.0617           +0.5064j            1.1763            0.4292
# AR.3            0.0816           -1.3804j            1.3828           -0.2406
# AR.4            0.0816           +1.3804j            1.3828            0.2406
# AR.5            2.9315           -0.0000j            2.9315           -0.0000
# -----------------------------------------------------------------------------
#                 0
# count   35.000000
# mean    -5.495267
# std     68.132879
# min   -133.296649
# 25%    -42.477975
# 50%     -7.186677
# 75%     24.748283
# max    133.237923

# %%
from pandas import read_csv
from pandas import datetime
from matplotlib import pyplot
from statsmodels.tsa.arima_model import ARIMA
from sklearn.metrics import mean_squared_error

def parser(x):
	return datetime.strptime('190'+x, '%Y-%m')

series = read_csv('shampoo.csv', header=0, parse_dates=[0], index_col=0, squeeze=True, date_parser=parser)
X = series.values
size = int(len(X) * 0.66)
train, test = X[0:size], X[size:len(X)]
history = [x for x in train]
predictions = list()
for t in range(len(test)):
	model = ARIMA(history, order=(5,1,0))
	model_fit = model.fit(disp=0)
	output = model_fit.forecast()
	yhat = output[0]
	predictions.append(yhat)
	obs = test[t]
	history.append(obs)
	print('predicted=%f, expected=%f' % (yhat, obs))
error = mean_squared_error(test, predictions)
print('Test MSE: %.3f' % error)
# plot
pyplot.plot(test)
pyplot.plot(predictions, color='red')
pyplot.show()
# Out:
# predicted=349.117705, expected=342.300000
# predicted=306.512977, expected=339.700000
# predicted=387.376388, expected=440.400000
# predicted=348.154194, expected=315.900000
# predicted=386.308770, expected=439.300000
# predicted=356.081960, expected=401.300000
# predicted=446.379501, expected=437.400000
# predicted=394.737276, expected=575.500000
# predicted=434.915504, expected=407.600000
# predicted=507.923350, expected=682.000000
# predicted=435.482832, expected=475.300000
# predicted=652.743765, expected=581.300000
# predicted=546.343452, expected=646.900000
# Test MSE: 6958.330

# %% [markdown]
# ## Trying ARIMA model on Trajectory Data

# %%
from pandas import read_csv, DataFrame
from pandas import datetime
from matplotlib import pyplot

def parser(x):
    return datetime.strptime('190'+x, '%Y-%m')

df = read_csv('steps_train.txt', skiprows=1, header=None, usecols=[1,2])
series = DataFrame((df[1]+df[2])/2)
print(series.head())
series.plot()
pyplot.show()
# Out:
#        0
# 0  0.000
# 1 -0.105
# 2  0.035
# 3  0.435
# 4  0.630

# %%
# Finding autocorrelation with pandas
from pandas import read_csv
from pandas import datetime
from matplotlib import pyplot
from pandas.plotting import autocorrelation_plot

def parser(x):
    return datetime.strptime('190'+x, '%Y-%m')

df = read_csv('steps_train.txt', skiprows=1, header=None, usecols=[1,2])
series = DataFrame((df[1]+df[2])/2)
autocorrelation_plot(series)
pyplot.show()

# %%
from pandas import read_csv
from pandas import datetime
from pandas import DataFrame, Series
from statsmodels.tsa.arima_model import ARIMA
from matplotlib import pyplot

def parser(x):
	return datetime.strptime('190'+x, '%Y-%m')

df = read_csv('steps_train.txt', skiprows=1, header=None, usecols=[1,2])
series = Series((df[1]+df[2])/2)
# fit model
model = ARIMA(series, order=(5,1,0))
model_fit = model.fit(disp=0)
print(model_fit.summary())
# plot residual errors
residuals = DataFrame(model_fit.resid)
residuals.plot()
pyplot.show()
residuals.plot(kind='kde')
pyplot.show()
print(residuals.describe())
# Out:
#                              ARIMA Model Results
# ==============================================================================
# Dep. Variable:                    D.y   No. Observations:                  748
# Model:                 ARIMA(5, 1, 0)   Log Likelihood                -160.697
# Method:                       css-mle   S.D. of innovations              0.300
# Date:                Tue, 18 Feb 2020   AIC                            335.394
# Time:                        11:07:13   BIC                            367.716
# Sample:                             1   HQIC                           347.850
#
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0033      0.113     -0.030      0.976      -0.224       0.217
# ar.L1.D.y      0.8607      0.037     23.535      0.000       0.789       0.932
# ar.L2.D.y     -0.0407      0.048     -0.842      0.400      -0.135       0.054
# ar.L3.D.y      0.1125      0.048      2.337      0.019       0.018       0.207
# ar.L4.D.y     -0.0373      0.048     -0.769      0.442      -0.132       0.058
# ar.L5.D.y      0.0087      0.037      0.238      0.812      -0.063       0.081
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1            1.0935           -0.0000j            1.0935           -0.0000
# AR.2           -1.2129           -2.1862j            2.5001           -0.3306
# AR.3           -1.2129           +2.1862j            2.5001            0.3306
# AR.4            2.8044           -2.9854j            4.0960           -0.1300
# AR.5            2.8044           +2.9854j            4.0960            0.1300
# -----------------------------------------------------------------------------
#                 0
# count  748.000000
# mean     0.000085
# std      0.299857
# min     -1.130859
# 25%     -0.078928
# 50%      0.002909
# 75%      0.087954
# max      1.288581

# %%
from pandas import read_csv
from pandas import datetime
from matplotlib import pyplot
from statsmodels.tsa.arima_model import ARIMA
from sklearn.metrics import mean_squared_error

def parser(x):
	return datetime.strptime('190'+x, '%Y-%m')

df = read_csv('steps_train.txt', skiprows=1, header=None, usecols=[1,2])
train = Series((df[1]+df[2])/2)
df = read_csv('steps_test.txt', skiprows=1, nrows=250, header=None, usecols=[1,2])
test = Series((df[1]+df[2])/2)
size = int(len(X) * 0.66)
# train, test = X[0:size], X[size:len(X)]
history = [x for x in train]
predictions = list()
for t in range(len(test)):
	model = ARIMA(history, order=(5,1,0))
	model_fit = model.fit(disp=0)
	output = model_fit.forecast()
	yhat = output[0]
	predictions.append(yhat)
	obs = test[t]
	history.append(obs)
	print('predicted=%f, expected=%f' % (yhat, obs))
error = mean_squared_error(test, predictions)
print('Test MSE: %.3f' % error)
# plot
pyplot.plot(test)
pyplot.plot(predictions, color='red')
pyplot.show()
# Out:
# predicted=0.429152, expected=0.735000
# predicted=0.801675, expected=0.375000
# predicted=0.033576, expected=0.560000
# predicted=0.741787, expected=1.410000
# predicted=2.091255, expected=2.140000
# predicted=2.768234, expected=2.850000
# predicted=3.518986, expected=3.560000
# predicted=4.197552, expected=4.185000
# predicted=4.754706, expected=4.840000
# predicted=5.438998, expected=5.340000
# predicted=5.794924, expected=5.225000
# predicted=5.161376, expected=4.655000
# predicted=4.201434, expected=3.985000
# predicted=3.400179, expected=3.335000
# predicted=2.742808, expected=2.685000
# predicted=2.094878, expected=2.105000
# predicted=1.580000, expected=2.330000
# predicted=2.500550, expected=2.955000
# predicted=3.449749, expected=3.685000
# predicted=4.339640, expected=4.490000
# predicted=5.219365, expected=5.325000
# predicted=6.075357, expected=6.240000
# predicted=7.063863, expected=7.045000
# predicted=7.769584, expected=7.715000
# predicted=8.333702, expected=8.380000
# predicted=8.985573, expected=9.040000
# predicted=9.631238, expected=9.645000
# predicted=10.192975, expected=10.320000
# predicted=10.931548, expected=11.025000
# predicted=11.654222, expected=11.700000
# predicted=12.311418, expected=12.375000
# predicted=12.988459, expected=12.985000
# predicted=13.537319, expected=13.695000
# predicted=14.339147, expected=14.395000
# predicted=15.019168, expected=14.875000
# predicted=15.320140, expected=15.410000
# predicted=15.908194, expected=14.880000
# predicted=14.420822, expected=14.245000
# predicted=13.751106, expected=13.615000
# predicted=13.014336, expected=12.965000
# predicted=12.377676, expected=12.305000
# predicted=11.713952, expected=11.570000
# predicted=10.911092, expected=10.895000
# predicted=10.291404, expected=10.235000
# predicted=9.634486, expected=9.575000
# predicted=8.982928, expected=8.895000
# predicted=8.284437, expected=8.210000
# predicted=7.595033, expected=7.560000
# predicted=6.973699, expected=6.865000
# predicted=6.237803, expected=6.200000
# predicted=5.604693, expected=5.620000
# predicted=5.091899, expected=4.950000
# predicted=4.344085, expected=4.320000
# predicted=3.760498, expected=3.685000
# predicted=3.106506, expected=3.050000
# predicted=2.479276, expected=2.420000
# predicted=1.851416, expected=1.820000
# predicted=1.277615, expected=1.155000
# predicted=0.554645, expected=0.580000
# predicted=0.064182, expected=0.675000
# predicted=0.736254, expected=1.065000
# predicted=1.370530, expected=0.515000
# predicted=0.046479, expected=-0.115000
# predicted=-0.601257, expected=-0.395000
# predicted=-0.684322, expected=0.145000
# predicted=0.581586, expected=0.595000
# predicted=0.948728, expected=1.215000
# predicted=1.802259, expected=0.945000
# predicted=0.707902, expected=0.025000
# predicted=-0.721882, expected=-0.805000
# predicted=-1.525216, expected=-1.420000
# predicted=-1.990297, expected=-2.015000
# predicted=-2.561613, expected=-2.310000
# predicted=-2.578554, expected=-1.665000
# predicted=-1.117879, expected=-1.000000
# predicted=-0.464044, expected=-0.275000
# predicted=0.396231, expected=0.480000
# predicted=1.149167, expected=0.785000
# predicted=1.061824, expected=1.060000
# predicted=1.339460, expected=1.930000
# predicted=2.697853, expected=2.650000
# predicted=3.258491, expected=3.140000
# predicted=3.609780, expected=3.740000
# predicted=4.286492, expected=4.325000
# predicted=4.838632, expected=4.830000
# predicted=5.291594, expected=5.205000
# predicted=5.548519, expected=5.190000
# predicted=5.187975, expected=4.620000
# predicted=4.137054, expected=3.900000
# predicted=3.284244, expected=3.165000
# predicted=2.502794, expected=2.435000
# predicted=1.780511, expected=1.790000
# predicted=1.211086, expected=2.020000
# predicted=2.219902, expected=2.665000
# predicted=3.186878, expected=3.345000
# predicted=3.953870, expected=4.080000
# predicted=4.743798, expected=4.885000
# predicted=5.602002, expected=5.785000
# predicted=6.589722, expected=6.635000
# predicted=7.393024, expected=7.235000
# Test MSE: 0.101
